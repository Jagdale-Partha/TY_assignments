# %% [markdown]
# # 02. Spatial Filtering
#
# This notebook covers spatial domain filtering, smoothing (low-pass), sharpening (high-pass), and custom convolution kernels.

# %%
import sys
sys.path.append('../common')

import cv2
import numpy as np
import matplotlib.pyplot as plt
from visualizer import show_image, compare_images

# %%
# Add spatial filtering experiments here
