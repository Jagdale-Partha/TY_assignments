# %% [markdown]
# # 01. Pixel Analysis
#
# This notebook covers pixel-level operations, intensity transformations, and histogram analysis.

# %%
import sys
sys.path.append('../common')

import cv2
import numpy as np
import matplotlib.pyplot as plt
from visualizer import show_image, plot_histogram

# %%
# Add pixel analysis experiments here
